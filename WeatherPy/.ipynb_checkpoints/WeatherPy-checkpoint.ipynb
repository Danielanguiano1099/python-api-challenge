# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 588

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    units = "metric"
    city_url = f"{url}appid={weather_api_key}&units={units}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | tagusao
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | harlow
# Processing Record 4 of Set 1 | carnarvon
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | bethanien
# Processing Record 10 of Set 1 | nexo
# Processing Record 11 of Set 1 | fairbanks
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | airai
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | georgetown
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | road town
# Processing Record 21 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 1 | bengkulu
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | pacific grove
# Processing Record 25 of Set 1 | wake forest
# Processing Record 26 of Set 1 | mao
# Processing Record 27 of Set 1 | hasaki
# Processing Record 28 of Set 1 | aleksandrov gay
# Processing Record 29 of Set 1 | bara
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | tuensang
# Processing Record 32 of Set 1 | alice springs
# Processing Record 33 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 1 | torbay
# Processing Record 35 of Set 1 | flinders
# Processing Record 36 of Set 1 | yulara
# Processing Record 37 of Set 1 | port elizabeth
# Processing Record 38 of Set 1 | camana
# Processing Record 39 of Set 1 | lugovoy
# Processing Record 40 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 1 | port hawkesbury
# Processing Record 42 of Set 1 | san policarpo
# Processing Record 43 of Set 1 | horodenka
# Processing Record 44 of Set 1 | bilma
# Processing Record 45 of Set 1 | nedjo
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | ilulissat
# Processing Record 48 of Set 1 | lompoc
# Processing Record 49 of Set 1 | iquitos
# Processing Record 50 of Set 1 | port-gentil
# Processing Record 0 of Set 2 | cape town
# Processing Record 1 of Set 2 | chuhar kana
# Processing Record 2 of Set 2 | lata
# Processing Record 3 of Set 2 | seymchan
# Processing Record 4 of Set 2 | coquimbo
# Processing Record 5 of Set 2 | auki
# Processing Record 6 of Set 2 | tucurui
# Processing Record 7 of Set 2 | alugan
# Processing Record 8 of Set 2 | saint-pierre
# Processing Record 9 of Set 2 | magdagachi
# Processing Record 10 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 2 | thompson
# Processing Record 12 of Set 2 | dingle
# Processing Record 13 of Set 2 | lebu
# Processing Record 14 of Set 2 | yellowknife
# Processing Record 15 of Set 2 | wasilla
# Processing Record 16 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 2 | berlevag
# Processing Record 18 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 2 | youghal
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | iquique
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | pisco
# Processing Record 24 of Set 2 | lagoa
# Processing Record 25 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 2 | cordoba
# Processing Record 27 of Set 2 | ust-tsilma
# Processing Record 28 of Set 2 | ayan
# Processing Record 29 of Set 2 | khatanga
# Processing Record 30 of Set 2 | derzhavinsk
# Processing Record 31 of Set 2 | port alfred
# Processing Record 32 of Set 2 | adolfo lopez mateos
# Processing Record 33 of Set 2 | itapecerica
# Processing Record 34 of Set 2 | cesenatico
# Processing Record 35 of Set 2 | muzquiz
# City not found. Skipping...
# Processing Record 36 of Set 2 | puerto ayora
# Processing Record 37 of Set 2 | arraial do cabo
# Processing Record 38 of Set 2 | east london
# Processing Record 39 of Set 2 | kalmunai
# Processing Record 40 of Set 2 | rundu
# Processing Record 41 of Set 2 | pevek
# Processing Record 42 of Set 2 | kathmandu
# Processing Record 43 of Set 2 | cabo san lucas
# Processing Record 44 of Set 2 | qinhuangdao
# Processing Record 45 of Set 2 | butaritari
# Processing Record 46 of Set 2 | pensacola
# Processing Record 47 of Set 2 | albany
# Processing Record 48 of Set 2 | turukhansk
# Processing Record 49 of Set 2 | rudnichnyy
# Processing Record 0 of Set 3 | bethel
# Processing Record 1 of Set 3 | manokwari
# Processing Record 2 of Set 3 | belmonte
# Processing Record 3 of Set 3 | cayenne
# Processing Record 4 of Set 3 | kavaratti
# Processing Record 5 of Set 3 | kryvyy rih
# Processing Record 6 of Set 3 | ponta delgada
# Processing Record 7 of Set 3 | honiara
# Processing Record 8 of Set 3 | nanortalik
# Processing Record 9 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 3 | vila franca do campo
# Processing Record 11 of Set 3 | hermanus
# Processing Record 12 of Set 3 | williston
# Processing Record 13 of Set 3 | zhezkazgan
# Processing Record 14 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 3 | mataura
# Processing Record 16 of Set 3 | norman wells
# Processing Record 17 of Set 3 | castro
# Processing Record 18 of Set 3 | mayo
# Processing Record 19 of Set 3 | port lincoln
# Processing Record 20 of Set 3 | victoria
# Processing Record 21 of Set 3 | egvekinot
# Processing Record 22 of Set 3 | saint-joseph
# Processing Record 23 of Set 3 | bambous virieux
# Processing Record 24 of Set 3 | souillac
# Processing Record 25 of Set 3 | maniitsoq
# Processing Record 26 of Set 3 | atwater
# Processing Record 27 of Set 3 | salalah
# Processing Record 28 of Set 3 | aklavik
# Processing Record 29 of Set 3 | burica
# City not found. Skipping...
# Processing Record 30 of Set 3 | mar del plata
# Processing Record 31 of Set 3 | grafton
# Processing Record 32 of Set 3 | barrow
# Processing Record 33 of Set 3 | dikson
# Processing Record 34 of Set 3 
of Set 5 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 12 of Set 5 | vestmannaeyjar
# Processing Record 13 of Set 5 | bujumbura
# Processing Record 14 of Set 5 | new norfolk
# Processing Record 15 of Set 5 | nikolskoye
# Processing Record 16 of Set 5 | sungairaya
# Processing Record 17 of Set 5 | eureka
# Processing Record 18 of Set 5 | tuatapere
# Processing Record 19 of Set 5 | vestmanna
# Processing Record 20 of Set 5 | wairoa
# Processing Record 21 of Set 5 | cap malheureux
# Processing Record 22 of Set 5 | husavik
# Processing Record 23 of Set 5 | mount isa
# Processing Record 24 of Set 5 | tuktoyaktuk
# Processing Record 25 of Set 5 | abeche
# Processing Record 26 of Set 5 | guerrero negro
# Processing Record 27 of Set 5 | port hardy
# Processing Record 28 of Set 5 | myaundzha
# Processing Record 29 of Set 5 | iaciara
# Processing Record 30 of Set 5 | cherdyn
# Processing Record 31 of Set 5 | grindavik
# Processing Record 32 of Set 5 | palmer
# Processing Record 33 of Set 5 | geraldton
# Processing Record 34 of Set 5 | saint-francois
# Processing Record 35 of Set 5 | voznesenye
# Processing Record 36 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 5 | tilichiki
# Processing Record 38 of Set 5 | pontes e lacerda
# Processing Record 39 of Set 5 | macae
# Processing Record 40 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 5 | cervo
# Processing Record 42 of Set 5 | sobolevo
# Processing Record 43 of Set 5 | mahebourg
# Processing Record 44 of Set 5 | biloela
# Processing Record 45 of Set 5 | paita
# Processing Record 46 of Set 5 | batetskiy
# Processing Record 47 of Set 5 | bokoro
# Processing Record 48 of Set 5 | margate
# Processing Record 49 of Set 5 | kozelsk
# Processing Record 0 of Set 6 | blackwater
# Processing Record 1 of Set 6 | cap-aux-meules
# Processing Record 2 of Set 6 | saint george
# Processing Record 3 of Set 6 | antofagasta
# Processing Record 4 of Set 6 | hondo
# Processing Record 5 of Set 6 | connersville
# Processing Record 6 of Set 6 | vanimo
# Processing Record 7 of Set 6 | shitkino
# Processing Record 8 of Set 6 | liverpool
# Processing Record 9 of Set 6 | asosa
# Processing Record 10 of Set 6 | kaitangata
# Processing Record 11 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 12 of Set 6 | boyolangu
# Processing Record 13 of Set 6 | barcelos
# Processing Record 14 of Set 6 | baijiantan
# Processing Record 15 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 16 of Set 6 | vryburg
# Processing Record 17 of Set 6 | jalu
# Processing Record 18 of Set 6 | sao cristovao
# Processing Record 19 of Set 6 | mahajanga
# Processing Record 20 of Set 6 | cazaje
# City not found. Skipping...
# Processing Record 21 of Set 6 | verkhoyansk
# Processing Record 22 of Set 6 | magistralnyy
# Processing Record 23 of Set 6 | grande-riviere
# City not found. Skipping...
# Processing Record 24 of Set 6 | houston
# Processing Record 25 of Set 6 | safaga
# Processing Record 26 of Set 6 | phangnga
# Processing Record 27 of Set 6 | matay
# Processing Record 28 of Set 6 | portobelo
# Processing Record 29 of Set 6 | tucuman
# Processing Record 30 of Set 6 | koppies
# Processing Record 31 of Set 6 | salekhard
# Processing Record 32 of Set 6 | irbil
# Processing Record 33 of Set 6 | chaa-khol
# City not found. Skipping...
# Processing Record 34 of Set 6 | cidreira
# Processing Record 35 of Set 6 | fort nelson
# Processing Record 36 of Set 6 | yurgamysh
# Processing Record 37 of Set 6 | neuquen
# Processing Record 38 of Set 6 | svetlogorsk
# Processing Record 39 of Set 6 | wucheng
# Processing Record 40 of Set 6 | beringovskiy
# Processing Record 41 of Set 6 | upernavik
# Processing Record 42 of Set 6 | touros
# Processing Record 43 of Set 6 | tiksi
# Processing Record 44 of Set 6 | niquelandia
# Processing Record 45 of Set 6 | naica
# Processing Record 46 of Set 6 | tela
# Processing Record 47 of Set 6 | iqaluit
# Processing Record 48 of Set 6 | san pedro pinula
# Processing Record 49 of Set 6 | kristiansund
# Processing Record 0 of Set 7 | ostrovnoy
# Processing Record 1 of Set 7 | alofi
# Processing Record 2 of Set 7 | pangody
# Processing Record 3 of Set 7 | kendari
# Processing Record 4 of Set 7 | tabuk
# Processing Record 5 of Set 7 | dwarka
# Processing Record 6 of Set 7 | kaka
# Processing Record 7 of Set 7 | itumba
# Processing Record 8 of Set 7 | bonthe
# Processing Record 9 of Set 7 | padang
# Processing Record 10 of Set 7 | san carlos de bariloche
# Processing Record 11 of Set 7 | ahipara
# Processing Record 12 of Set 7 | anadyr
# Processing Record 13 of Set 7 | mountain home
# Processing Record 14 of Set 7 | along
# Processing Record 15 of Set 7 | te anau
# Processing Record 16 of Set 7 | los llanos de aridane
# Processing Record 17 of Set 7 | winnemucca
# Processing Record 18 of Set 7 | panzhihua
# Processing Record 19 of Set 7 | roald
# Processing Record 20 of Set 7 | fukue
# Processing Record 21 of Set 7 | iwanai
# Processing Record 22 of Set 7 | san rafael
# Processing Record 23 of Set 7 | carora
# Processing Record 24 of Set 7 | chokurdakh
# Processing Record 25 of Set 7 | myski
# Processing Record 26 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 7 | roebourne
# Processing Record 28 of Set 7 | tukrah
# Processing Record 29 of Set 7 | sibolga
# Processing Record 30 of Set 7 | pangai
# Processing Record 31 of Set 7 | alta gracia
# Processing Record 32 of Set 7 | lubao
# Processing Record 33 of Set 7 | mount vernon
# Processing Record 34 of Set 7 | tual
# Processing Record 35 of Set 7 | thinadhoo
# Processing Record 36 of Set 7 | henties bay
# Processing Record 37 of Set 7 | bichura
# Processing Record 38 of Set 7 | conakry
# Processing Record 39 of Set 7 | posse
# Processing Record 40 of Set 7 | jining
# Processing Record 41 of Set 7 | udachnyy
# Processing Record 42 of Set 7 | provideniya
# Processing Record 43 of Set 7 | kattivakkam
# Processing Record 44 of Set 7 | dhidhdhoo
# Processing Record 45 of Set 7 | san-pedro
# Processing Record 46 of Set 7 | meulaboh
# Processing Record 47 of Set 7 | andra
# Processing Record 48 of Set 7 | mildura
# Processing Record 49 of Set 7 | marawi
# Processing Record 0 of Set 8 | saint anthony
# Processing Record 1 of Set 8 | calabozo
# Processing Record 2 of Set 8 | luderitz
# Processing Record 3 of Set 8 | nauta
# Processing Record 4 of Set 8 | tambopata
# Processing Record 5 of Set 8 | saint-philippe
# Processing Record 6 of Set 8 | kawalu
# Processing Record 7 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 8 of Set
# Processing Record 38 of Set 9 | maceio
# Processing Record 39 of Set 9 | west memphis
# Processing Record 40 of Set 9 | selenginsk
# Processing Record 41 of Set 9 | feijo
# Processing Record 42 of Set 9 | falam
# Processing Record 43 of Set 9 | berezna
# Processing Record 44 of Set 9 | andros town
# Processing Record 45 of Set 9 | kutum
# Processing Record 46 of Set 9 | kenai
# Processing Record 47 of Set 9 | constitucion
# Processing Record 48 of Set 9 | gobabis
# Processing Record 49 of Set 9 | sangre grande
# Processing Record 0 of Set 10 | big spring
# Processing Record 1 of Set 10 | kasempa
# Processing Record 2 of Set 10 | ancud
# Processing Record 3 of Set 10 | pasighat
# Processing Record 4 of Set 10 | milingimbi
# City not found. Skipping...
# Processing Record 5 of Set 10 | parrita
# Processing Record 6 of Set 10 | bouna
# Processing Record 7 of Set 10 | kavieng
# Processing Record 8 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 9 of Set 10 | dong hoi
# Processing Record 10 of Set 10 | palana
# Processing Record 11 of Set 10 | holme
# Processing Record 12 of Set 10 | mazulskiy
# City not found. Skipping...
# Processing Record 13 of Set 10 | mareeba
# Processing Record 14 of Set 10 | kununurra
# Processing Record 15 of Set 10 | nome
# Processing Record 16 of Set 10 | san cristobal
# Processing Record 17 of Set 10 | bonavista
# Processing Record 18 of Set 10 | hurghada
# Processing Record 19 of Set 10 | petropavl
# Processing Record 20 of Set 10 | ossora
# Processing Record 21 of Set 10 | bay roberts
# Processing Record 22 of Set 10 | causapscal
# Processing Record 23 of Set 10 | goderich
# Processing Record 24 of Set 10 | dalnerechensk
# Processing Record 25 of Set 10 | dali
# Processing Record 26 of Set 10 | loandjili
# Processing Record 27 of Set 10 | hami
# Processing Record 28 of Set 10 | streator
# Processing Record 29 of Set 10 | oranjestad
# Processing Record 30 of Set 10 | helong
# Processing Record 31 of Set 10 | vitim
# Processing Record 32 of Set 10 | qurunbaliyah
# City not found. Skipping...
# Processing Record 33 of Set 10 | karratha
# Processing Record 34 of Set 10 | tautira
# Processing Record 35 of Set 10 | poronaysk
# Processing Record 36 of Set 10 | chapais
# Processing Record 37 of Set 10 | songjianghe
# Processing Record 38 of Set 10 | broome
# Processing Record 39 of Set 10 | sao filipe
# Processing Record 40 of Set 10 | tuzla
# Processing Record 41 of Set 10 | graaff-reinet
# Processing Record 42 of Set 10 | moorhead
# Processing Record 43 of Set 10 | west odessa
# Processing Record 44 of Set 10 | rognan
# Processing Record 45 of Set 10 | okitipupa
# Processing Record 46 of Set 10 | la ronge
# Processing Record 47 of Set 10 | keflavik
# Processing Record 48 of Set 10 | isangel
# Processing Record 49 of Set 10 | bariadi
# Processing Record 0 of Set 11 | visnes
# Processing Record 1 of Set 11 | salvador
# Processing Record 2 of Set 11 | itarema
# Processing Record 3 of Set 11 | san patricio
# Processing Record 4 of Set 11 | wawa
# Processing Record 5 of Set 11 | voi
# Processing Record 6 of Set 11 | tadine
# Processing Record 7 of Set 11 | manicore
# Processing Record 8 of Set 11 | rockhampton
# Processing Record 9 of Set 11 | dubbo
# Processing Record 10 of Set 11 | ozieri
# Processing Record 11 of Set 11 | astara
# Processing Record 12 of Set 11 | zhanaozen
# Processing Record 13 of Set 11 | avera
# Processing Record 14 of Set 11 | rabo de peixe
# Processing Record 15 of Set 11 | waipawa
# Processing Record 16 of Set 11 | alyangula
# Processing Record 17 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 11 | riverton
# Processing Record 19 of Set 11 | ayni
# Processing Record 20 of Set 11 | samarai
# Processing Record 21 of Set 11 | aksay
# Processing Record 22 of Set 11 | nizhniy odes
# Processing Record 23 of Set 11 | clyde river
# Processing Record 24 of Set 11 | borgarnes
# Processing Record 25 of Set 11 | vila velha
# Processing Record 26 of Set 11 | dustlik
# Processing Record 27 of Set 11 | kayes
# Processing Record 28 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 29 of Set 11 | mahina
# Processing Record 30 of Set 11 | luangwa
# Processing Record 31 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 32 of Set 11 | korla
# Processing Record 33 of Set 11 | gerash
# Processing Record 34 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 35 of Set 11 | umbuzeiro
# Processing Record 36 of Set 11 | manacapuru
# Processing Record 37 of Set 11 | sola
# Processing Record 38 of Set 11 | rawson
# Processing Record 39 of Set 11 | watertown
# Processing Record 40 of Set 11 | minab
# Processing Record 41 of Set 11 | byron bay
# Processing Record 42 of Set 11 | san juan bautista
# Processing Record 43 of Set 11 | hualmay
# Processing Record 44 of Set 11 | yanam
# Processing Record 45 of Set 11 | ondjiva
# Processing Record 46 of Set 11 | kungurtug
# Processing Record 47 of Set 11 | rio grande
# Processing Record 48 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 11 | faanui
# Processing Record 0 of Set 12 | uaua
# Processing Record 1 of Set 12 | dudinka
# Processing Record 2 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 12 | olesnica
# Processing Record 4 of Set 12 | bubaque
# Processing Record 5 of Set 12 | slave lake
# Processing Record 6 of Set 12 | algiers
# Processing Record 7 of Set 12 | los angeles
# Processing Record 8 of Set 12 | batemans bay
# Processing Record 9 of Set 12 | buraydah
# Processing Record 10 of Set 12 | satipo
# Processing Record 11 of Set 12 | mucurapo
# Processing Record 12 of Set 12 | grand gaube
# Processing Record 13 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 14 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 12 | wembley
# Processing Record 16 of Set 12 | cabedelo
# Processing Record 17 of Set 12 | coihaique
# Processing Record 18 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 12 | hilton head island
# Processing Record 20 of Set 12 | townsville
# Processing Record 21 of Set 12 | umba
# Processing Record 22 of Set 12 | birjand
# Processing Record 23 of Set 12 | mezen
# Processing Record 24 of Set 12 | blagoyevo
# Processing Record 25 of Set 12 | grand-santi
# Processing Record 26 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 12 | tarko-sale
# Processing Record 28 of Set 12 | odweyne
# Processing Record 29 of Set 12 | hirara
# Processing Record 30 of Set 12 | thunder bay
# Processing Record 31 of Set 12 | erenhot
# Processing Record 32 of Set 12 | hemnes
# City not found. Skipping...
# Processing Record 33 of Set 12 | ahuimanu
# Processing Record 34 of Set 12 | mount hagen
# Processing Record 35 of Set 12 | north bend
# Processing Record 36 of Set 12 | umm lajj
# Processing Record 37 of Set 12 | abu samrah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          538
# Lat           538
# Lng           538
# Max Temp      538
# Humidity      538
# Cloudiness    538
# Wind Speed    538
# Country       538
# Date          538
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    tagusao   9.1924  117.8141     25.87        84          57        1.88
# 1     harlow  51.7766    0.1116      0.56        91          11        2.06
# 2  carnarvon -24.8667  113.6333     21.98        61          57        6.50
# 3    qaanaaq  77.4840  -69.3632    -11.13        67          83        3.76
# 4  busselton -33.6500  115.3333     16.99        72          53        2.81
#
#   Country        Date
# 0      PH  1670454750
# 1      GB  1670454751
# 2      AU  1670454751
# 3      GL  1670454752
# 4      AU  1670454541

# %%
# Export the City_Data into a csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          tagusao   9.1924  117.8141     25.87        84          57
# 1           harlow  51.7766    0.1116      0.56        91          11
# 2        carnarvon -24.8667  113.6333     21.98        61          57
# 3          qaanaaq  77.4840  -69.3632    -11.13        67          83
# 4        busselton -33.6500  115.3333     16.99        72          53
#
#          Wind Speed Country        Date
# City_ID
# 0              1.88      PH  1670454750
# 1              2.06      GB  1670454751
# 2              6.50      AU  1670454751
# 3              3.76      GL  1670454752
# 4              2.81      AU  1670454541

# %%
lat_v_temp_df = city_data_df.loc[:, ["Lat","Max Temp"]]
lat_v_temp_df
# Out:
#              Lat  Max Temp
# City_ID
# 0         9.1924     25.87
# 1        51.7766      0.56
# 2       -24.8667     21.98
# 3        77.4840    -11.13
# 4       -33.6500     16.99
# ...          ...       ...
# 533      21.4447     27.84
# 534      -5.8581     19.71
# 535      43.4065      8.42
# 536      25.0213     22.67
# 537      35.3029     12.68
#
# [538 rows x 2 columns]

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
lat_v_temp_df.plot.scatter("Lat", "Max Temp")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")
plt.title("Latitude vs. Max Temp (C)")
plt.grid()
# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("Fig1.png")
# Show plot
plt.show()

# %%
lat_v_humid_df = city_data_df.loc[:, ["Lat","Humidity"]]
lat_v_humid_df
# Out:
#              Lat  Humidity
# City_ID
# 0         9.1924        84
# 1        51.7766        91
# 2       -24.8667        61
# 3        77.4840        67
# 4       -33.6500        72
# ...          ...       ...
# 533      21.4447        73
# 534      -5.8581        80
# 535      43.4065        94
# 536      25.0213        69
# 537      35.3029        71
#
# [538 rows x 2 columns]

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
lat_v_humid_df.plot.scatter("Lat", "Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Latitude vs. Humidity (2022-12-7)")
plt.grid()
# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("Fig2.png")
# Show plot
plt.show()

# %%
lat_v_cloud_df = city_data_df.loc[:, ["Lat","Cloudiness"]]
lat_v_cloud_df
# Out:
#              Lat  Cloudiness
# City_ID
# 0         9.1924          57
# 1        51.7766          11
# 2       -24.8667          57
# 3        77.4840          83
# 4       -33.6500          53
# ...          ...         ...
# 533      21.4447          75
# 534      -5.8581          94
# 535      43.4065         100
# 536      25.0213           0
# 537      35.3029         100
#
# [538 rows x 2 columns]

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
lat_v_cloud_df.plot.scatter("Lat", "Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Latitude vs. Cloudiness (2022-12-7)")
plt.grid()
# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("Fig3.png")
# Show plot
plt.show()

# %%
lat_v_wind_df = city_data_df.loc[:, ["Lat","Wind Speed"]]
lat_v_wind_df
# Out:
#              Lat  Wind Speed
# City_ID
# 0         9.1924        1.88
# 1        51.7766        2.06
# 2       -24.8667        6.50
# 3        77.4840        3.76
# 4       -33.6500        2.81
# ...          ...         ...
# 533      21.4447        8.75
# 534      -5.8581        0.47
# 535      43.4065        5.14
# 536      25.0213        4.55
# 537      35.3029        1.83
#
# [538 rows x 2 columns]

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
lat_v_wind_df.plot.scatter("Lat", "Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Latitude vs. Wind Speed (2022-12-7)")
plt.grid()
# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("Fig4.png")
# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE
def regression_plot(x, y, y_col, hemi):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y, marker="o", facecolors="blue", edgecolors="blue", alpha=.5)
    plt.plot(x, regress_values, "r-")
    plt.annotate(line_eq,(min(x), min(y)),fontsize=15,color="red")
    plt.xlabel("Latitude (" + hemi + ")")
    plt.ylabel(y_col)
    print('The r-value is: ' + str(rvalue ** 2))
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          tagusao   9.1924  117.8141     25.87        84          57
# 1           harlow  51.7766    0.1116      0.56        91          11
# 3          qaanaaq  77.4840  -69.3632    -11.13        67          83
# 7             nexo  55.0607   15.1306      1.05        89          99
# 8        fairbanks  64.8378 -147.7164     -6.71        90         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.88      PH  1670454750
# 1              2.06      GB  1670454751
# 3              3.76      GL  1670454752
# 7              6.89      DK  1670454754
# 8              0.00      US  1670454265

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2           carnarvon -24.8667  113.6333     21.98        61          57
# 4           busselton -33.6500  115.3333     16.99        72          53
# 5        punta arenas -53.1500  -70.9167      8.95        61           0
# 6           bethanien -26.5020   17.1583     20.15        31           0
# 11              airai  -8.9266  125.4092     19.25        57          78
#
#          Wind Speed Country        Date
# City_ID
# 2              6.50      AU  1670454751
# 4              2.81      AU  1670454541
# 5              7.72      CL  1670454622
# 6              2.51     NaN  1670454753
# 11             0.72      TL  1670454756

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], "Max Temp", "Northern Hemisphere")
# Out:
# The r-value is: 0.7102359160025098

# %%
# Linear regression on Southern Hemisphere
regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], "Max Temp", "Southern Hemisphere")
# Out:
# The r-value is: 0.2644402269926772

# %%
# There is a strong negative correlation between the Northern Hemisphere Max Temp vs Latitude, as the latitude increases, the Max Temp decreases.
# There is a weak positive correlation between the Southern Hemisphere Max Temp vs Latitude, as the latitude increases, The Max Temp increase
# It makes sense intuitively as you get closer to the equator, the temperature increases, as you move away the temp decreases.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], "Humidity", "Northern Hemisphere")
# Out:
# The r-value is: 0.1277155643215641

# %%
# Southern Hemisphere
regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], "Humidity", "Southern Hemisphere")
# Out:
# The r-value is: 0.1264460211975698

# %%
# There is a weak positive correlation between the Northern Hemisphere HUmidity vs Latitude, as the latitude increases, the Humidity increase.
# There is a weak positive correlation between the Southern Hemisphere Humidity vs Latitude, as the latitude increases, The Humidityincrease

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], "Cloudiness", "Northern Hemisphere")
# Out:
# The r-value is: 0.06053898931010815

# %%
# Southern Hemisphere
regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], "Cloudiness", "Southern Hemisphere")
# Out:
# The r-value is: 0.029769688841069918

# %%
# There is almost no correlation on both Northern and Southern Hemisphere between Latitude and Cloudiness

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], "Wind Speed", "Northern Hemisphere")
# Out:
# The r-value is: 0.015447608679263695

# %%
# Southern Hemisphere
regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], "Wind Speed", "Southern Hemisphere")
# Out:
# The r-value is: 0.13897476975965456

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
# Northern Hemisphere almost has no correlation between Latitude and Windspeed.
# While the southern Hemisphere has some correlation, it is not very strong.
